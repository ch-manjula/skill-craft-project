# %%
import pandas as pd

# Load the dataset
df = pd.read_csv(r"C:\Users\Administrator\Downloads\gender_submission.csv")

# Display the first few rows
print(df.head())
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# dtype: int64

# %%
# Display data types
print(df.dtypes)
# Out:
# PassengerId    int64
# Survived       int64
# dtype: object

# %%
print(df.describe())
# Out:
#        PassengerId    Survived
# count   418.000000  418.000000
# mean   1100.500000    0.363636
# std     120.810458    0.481622
# min     892.000000    0.000000
# 25%     996.250000    0.000000
# 50%    1100.500000    0.000000
# 75%    1204.750000    1.000000
# max    1309.000000    1.000000

# %%
import matplotlib.pyplot as plt

# Calculate survival rate
survival_counts = df["Survived"].value_counts()

# Create a bar chart
plt.figure(figsize=(6,4))
survival_counts.plot(kind='bar', color=['red', 'green'])
plt.xlabel("Survived (0 = No, 1 = Yes)")
plt.ylabel("Number of Passengers")
plt.title("Survival Distribution")
plt.xticks(rotation=0)
plt.show()

# %%
plt.hist(df["PassengerId"], bins=20, edgecolor='black')
plt.xlabel("Passenger ID")
plt.ylabel("Frequency")
plt.title("Distribution of Passenger IDs")
plt.show()

# %%
import seaborn as sns

# Example if more columns were available
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
